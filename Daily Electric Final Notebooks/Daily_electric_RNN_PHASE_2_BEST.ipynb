# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
tf.test.gpu_device_name()

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Energy/Daily_electricity_consumption.csv')
df.head()
# Out:
#     date_time  active_power_consumed  meter_reading
# 0  01-01-2009               0.976869       1.946528
# 1  02-01-2009               1.616326       8.222917
# 2  03-01-2009               1.328817       7.249306
# 3  04-01-2009               1.347218       2.253472
# 4  05-01-2009               1.113889       6.006944

# %%
df.tail()
# Out:
#       date_time  active_power_consumed  meter_reading
# 690  22-11-2010               1.417733       7.038889
# 691  23-11-2010               1.095511       5.285417
# 692  24-11-2010               1.247394       8.488889
# 693  25-11-2010               0.993864       3.522222
# 694  26-11-2010               1.178230       7.908947

# %%
df.shape
# Out:
# (695, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date_time              695 non-null    object
#  1   active_power_consumed  695 non-null    float64
#  2   meter_reading          695 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 16.4+ KB

# %%
df.isnull().sum()
# Out:
# date_time                0
# active_power_consumed    0
# meter_reading            0
# dtype: int64

# %%
time = pd.date_range(start='1/1/2009',end='11/26/2010',freq='D')
df['time_stamp'] = pd.DataFrame(time)
df.drop('date_time',axis=1,inplace=True)
df = df.set_index('time_stamp')

# %%
len(time)
# Out:
# 695

# %%
df.head()
# Out:
#             active_power_consumed  meter_reading
# time_stamp
# 2009-01-01               0.976869       1.946528
# 2009-01-02               1.616326       8.222917
# 2009-01-03               1.328817       7.249306
# 2009-01-04               1.347218       2.253472
# 2009-01-05               1.113889       6.006944

# %%
df.tail()
# Out:
#             active_power_consumed  meter_reading
# time_stamp
# 2010-11-22               1.417733       7.038889
# 2010-11-23               1.095511       5.285417
# 2010-11-24               1.247394       8.488889
# 2010-11-25               0.993864       3.522222
# 2010-11-26               1.178230       7.908947

# %%
df = df[['active_power_consumed']]

# %%
df
# Out:
#             active_power_consumed
# time_stamp
# 2009-01-01               0.976869
# 2009-01-02               1.616326
# 2009-01-03               1.328817
# 2009-01-04               1.347218
# 2009-01-05               1.113889
# ...                           ...
# 2010-11-22               1.417733
# 2010-11-23               1.095511
# 2010-11-24               1.247394
# 2010-11-25               0.993864
# 2010-11-26               1.178230
#
# [695 rows x 1 columns]

# %%
plt.rcParams['figure.figsize'] = [15,8]

# %%
plt.plot(df,color='blue')
plt.title('Daily Electricity Consumption',fontsize=20)
plt.xlabel('Date',fontsize=15)
plt.ylabel('Units',fontsize=15)
plt.show()

# %%
def convert2matrix(data_arr, look_back):
    X, Y =[], []
    for i in range(len(data_arr)-look_back):
        d=i+look_back  
        X.append(data_arr[i:d,0])
        Y.append(data_arr[d,0])
    return np.array(X), np.array(Y)

# %%
#Split data set into testing dataset and train dataset
train_size = 618
train, test =df.values[0:train_size,:],df.values[train_size:len(df.values),:]
# setup look_back window 
look_back = 7
#convert dataset into right shape in order to input into the DNN
trainX, trainY = convert2matrix(train, look_back)
testX, testY = convert2matrix(test, look_back)
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (611, 1, 7)
# (611,)
# (70, 1, 7)
# (70,)

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 133 kB 4.5 MB/s

# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense,Dropout,SimpleRNN
from tensorflow.keras.layers import Flatten
import matplotlib.pyplot as plt

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(SimpleRNN(hp.Int('first_rnn_layer',min_value=8,max_value=128,step=8), activation="relu",return_sequences=True, input_shape=(1,look_back),recurrent_dropout = hp.Choice("first_recurrent_dropout",[0.2,0.4,0.6],default=0.4)))
    for i in range(hp.Int('n_layers', 1, 4)):
        model.add(SimpleRNN(hp.Int(f'rnn_{i}_units',min_value=8,max_value=128,step=8),activation="relu", return_sequences=True,recurrent_dropout = hp.Choice(f"recurrent_dropout_{i}",[0.2,0.4,0.6],default=0.4)))
    model.add(SimpleRNN(hp.Int('final_rnn_layer',min_value=8,max_value=128,step=8),activation="relu",recurrent_dropout = hp.Choice("last_recurrent_dropout",[0.2,0.4,0.6],default=0.4) ))
    model.add(Dense(hp.Int('dense_layer_1',min_value=8,max_value=128,step=8),activation="relu"))
    model.add(Dropout(hp.Float('Dropout_rate',min_value=0,max_value=0.5,step=0.1)))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
             hp.Float('learning_rate', min_value=1e-4, max_value=1e-1, sampling="log")),
        loss='mape',
        metrics=['mape'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mape',
    max_trials=20,
    executions_per_trial=2,
    directory='project',
    project_name='elec_consum')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 10
# first_rnn_layer (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 128, 'step': 8, 'sampling': None}
# first_recurrent_dropout (Choice)
# {'default': 0.4, 'conditions': [], 'values': [0.2, 0.4, 0.6], 'ordered': True}
# n_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 4, 'step': 1, 'sampling': None}
# rnn_0_units (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 128, 'step': 8, 'sampling': None}
# recurrent_dropout_0 (Choice)
# {'default': 0.4, 'conditions': [], 'values': [0.2, 0.4, 0.6], 'ordered': True}
# final_rnn_layer (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 128, 'step': 8, 'sampling': None}
# last_recurrent_dropout (Choice)
# {'default': 0.4, 'conditions': [], 'values': [0.2, 0.4, 0.6], 'ordered': True}
# dense_layer_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 128, 'step': 8, 'sampling': None}
# Dropout_rate (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.5, 'step': 0.1, 'sampling': None}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}

# %%
tuner.search(trainX, trainY,
             epochs=200,
             batch_size=33,
             validation_data=(testX, testY))
# Out:
# Trial 20 Complete [00h 01m 01s]
# val_mape: 19.6481351852417
#
# Best val_mape So Far: 17.40298366546631
# Total elapsed time: 00h 27m 05s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project/elec_consum
# Showing 10 best trials
# Objective(name='val_mape', direction='min')
# Trial summary
# Hyperparameters:
# first_rnn_layer: 48
# first_recurrent_dropout: 0.6
# n_layers: 3
# rnn_0_units: 56
# recurrent_dropout_0: 0.6
# final_rnn_layer: 96
# last_recurrent_dropout: 0.2
# dense_layer_1: 8
# Dropout_rate: 0.4
# learning_rate: 0.00177225433944805
# rnn_1_units: 40
# recurrent_dropout_1: 0.2
# rnn_2_units: 24
# recurrent_dropout_2: 0.6
# rnn_3_units: 24
# recurrent_dropout_3: 0.2
# Score: 17.40298366546631
# Trial summary
# Hyperparameters:
# first_rnn_layer: 64
# first_recurrent_dropout: 0.2
# n_layers: 2
# rnn_0_units: 16
# recurrent_dropout_0: 0.2
# final_rnn_layer: 112
# last_recurrent_dropout: 0.2
# dense_layer_1: 80
# Dropout_rate: 0.2
# learning_rate: 0.001972612994637945
# rnn_1_units: 8
# recurrent_dropout_1: 0.4
# Score: 18.50641918182373
# Trial summary
# Hyperparameters:
# first_rnn_layer: 24
# first_recurrent_dropout: 0.6
# n_layers: 2
# rnn_0_units: 120
# recurrent_dropout_0: 0.6
# final_rnn_layer: 40
# last_recurrent_dropout: 0.4
# dense_layer_1: 32
# Dropout_rate: 0.0
# learning_rate: 0.0023704919889749477
# rnn_1_units: 16
# recurrent_dropout_1: 0.6
# rnn_2_units: 120
# recurrent_dropout_2: 0.2
# rnn_3_units: 56
# recurrent_dropout_3: 0.2
# Score: 18.559289932250977
# Trial summary
# Hyperparameters:
# first_rnn_layer: 72
# first_recurrent_dropout: 0.4
# n_layers: 3
# rnn_0_units: 48
# recurrent_dropout_0: 0.2
# final_rnn_layer: 56
# last_recurrent_dropout: 0.2
# dense_layer_1: 40
# Dropout_rate: 0.4
# learning_rate: 0.0014920739790423448
# rnn_1_units: 64
# recurrent_dropout_1: 0.2
# rnn_2_units: 112
# recurrent_dropout_2: 0.4
# rnn_3_units: 72
# recurrent_dropout_3: 0.6
# Score: 18.670409202575684
# Trial summary
# Hyperparameters:
# first_rnn_layer: 16
# first_recurrent_dropout: 0.4
# n_layers: 3
# rnn_0_units: 80
# recurrent_dropout_0: 0.4
# final_rnn_layer: 32
# last_recurrent_dropout: 0.2
# dense_layer_1: 32
# Dropout_rate: 0.0
# learning_rate: 0.020861225744667783
# rnn_1_units: 64
# recurrent_dropout_1: 0.2
# rnn_2_units: 96
# recurrent_dropout_2: 0.4
# rnn_3_units: 32
# recurrent_dropout_3: 0.4
# Score: 18.7783842086792
# Trial summary
# Hyperparameters:
# first_rnn_layer: 56
# first_recurrent_dropout: 0.2
# n_layers: 1
# rnn_0_units: 112
# recurrent_dropout_0: 0.2
# final_rnn_layer: 48
# last_recurrent_dropout: 0.6
# dense_layer_1: 96
# Dropout_rate: 0.5
# learning_rate: 0.0024819137307728624
# rnn_1_units: 104
# recurrent_dropout_1: 0.2
# rnn_2_units: 80
# recurrent_dropout_2: 0.6
# rnn_3_units: 48
# recurrent_dropout_3: 0.6
# Score: 18.817837715148926
# Trial summary
# Hyperparameters:
# first_rnn_layer: 16
# first_recurrent_dropout: 0.4
# n_layers: 2
# rnn_0_units: 48
# recurrent_dropout_0: 0.6
# final_rnn_layer: 120
# last_recurrent_dropout: 0.6
# dense_layer_1: 72
# Dropout_rate: 0.1
# learning_rate: 0.00022481910373391807
# rnn_1_units: 64
# recurrent_dropout_1: 0.2
# Score: 18.90623950958252
# Trial summary
# Hyperparameters:
# first_rnn_layer: 40
# first_recurrent_dropout: 0.6
# n_layers: 1
# rnn_0_units: 16
# recurrent_dropout_0: 0.6
# final_rnn_layer: 120
# last_recurrent_dropout: 0.2
# dense_layer_1: 128
# Dropout_rate: 0.4
# learning_rate: 0.03132534607160715
# rnn_1_units: 72
# recurrent_dropout_1: 0.6
# rnn_2_units: 128
# recurrent_dropout_2: 0.4
# rnn_3_units: 88
# recurrent_dropout_3: 0.4
# Score: 18.92098331451416
# Trial summary
# Hyperparameters:
# first_rnn_layer: 104
# first_recurrent_dropout: 0.2
# n_layers: 4
# rnn_0_units: 88
# recurrent_dropout_0: 0.2
# final_rnn_layer: 104
# last_recurrent_dropout: 0.6
# dense_layer_1: 40
# Dropout_rate: 0.1
# learning_rate: 0.017909910243922317
# rnn_1_units: 40
# recurrent_dropout_1: 0.6
# rnn_2_units: 112
# recurrent_dropout_2: 0.4
# rnn_3_units: 88
# recurrent_dropout_3: 0.4
# Score: 19.02340793609619
# Trial summary
# Hyperparameters:
# first_rnn_layer: 120
# first_recurrent_dropout: 0.6
# n_layers: 3
# rnn_0_units: 88
# recurrent_dropout_0: 0.4
# final_rnn_layer: 88
# last_recurrent_dropout: 0.6
# dense_layer_1: 112
# Dropout_rate: 0.4
# learning_rate: 0.014448315026478068
# rnn_1_units: 88
# recurrent_dropout_1: 0.6
# rnn_2_units: 24
# recurrent_dropout_2: 0.2
# rnn_3_units: 104
# recurrent_dropout_3: 0.2
# Score: 19.048267364501953

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
models = tuner.get_best_models(num_models=2)
best_model = models[0]
# Build the model.
# Needed for `Sequential` without specified `input_shape`.
best_model.build(input_shape=(None, 10))
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 48)             2832
#
#  simple_rnn_1 (SimpleRNN)    (None, 1, 56)             5880
#
#  simple_rnn_2 (SimpleRNN)    (None, 1, 40)             3880
#
#  simple_rnn_3 (SimpleRNN)    (None, 1, 24)             1560
#
#  simple_rnn_4 (SimpleRNN)    (None, 96)                11616
#
#  dense (Dense)               (None, 8)                 776
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 26,553
# Trainable params: 26,553
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Bidirectional

# %%
model = Sequential()
model.add(SimpleRNN(16,activation='relu',input_shape=(1,look_back), return_sequences=True))
model.add(SimpleRNN(8,activation='relu'))
model.add(Dense(1,activation='linear'))
ad=optimizers.Adam(learning_rate=0.000100225433944805)
model.compile(optimizer = ad, loss = 'mape', metrics = ['mape'])
model_history=model.fit(trainX, trainY,validation_data=(testX, testY), batch_size = 33, epochs = 200)
# Out:
# Epoch 1/200
# 19/19 [==============================] - 3s 30ms/step - loss: 204.2192 - mape: 204.2192 - val_loss: 201.0839 - val_mape: 201.0839
# Epoch 2/200
# 19/19 [==============================] - 0s 6ms/step - loss: 198.5995 - mape: 198.5995 - val_loss: 195.6868 - val_mape: 195.6868
# Epoch 3/200
# 19/19 [==============================] - 0s 5ms/step - loss: 193.1276 - mape: 193.1276 - val_loss: 190.3952 - val_mape: 190.3952
# Epoch 4/200
# 19/19 [==============================] - 0s 5ms/step - loss: 187.7763 - mape: 187.7763 - val_loss: 185.2202 - val_mape: 185.2202
# Epoch 5/200
# 19/19 [==============================] - 0s 6ms/step - loss: 182.5179 - mape: 182.5179 - val_loss: 180.1275 - val_mape: 180.1275
# Epoch 6/200
# 19/19 [==============================] - 0s 6ms/step - loss: 177.3484 - mape: 177.3484 - val_loss: 175.0829 - val_mape: 175.0829
# Epoch 7/200
# 19/19 [==============================] - 0s 5ms/step - loss: 172.2410 - mape: 172.2410 - val_loss: 170.1118 - val_mape: 170.1118
# Epoch 8/200
# 19/19 [==============================] - 0s 6ms/step - loss: 167.1735 - mape: 167.1735 - val_loss: 165.1391 - val_mape: 165.1391
# Epoch 9/200
# 19/19 [==============================] - 0s 6ms/step - loss: 162.1044 - mape: 162.1044 - val_loss: 160.1618 - val_mape: 160.1618
# Epoch 10/200
# 19/19 [==============================] - 0s 6ms/step - loss: 157.0233 - mape: 157.0233 - val_loss: 155.1306 - val_mape: 155.1306
# Epoch 11/200
# 19/19 [==============================] - 0s 5ms/step - loss: 151.8880 - mape: 151.8880 - val_loss: 149.9817 - val_mape: 149.9817
# Epoch 12/200
# 19/19 [==============================] - 0s 7ms/step - loss: 146.6523 - mape: 146.6523 - val_loss: 144.7491 - val_mape: 144.7491
# Epoch 13/200
# 19/19 [==============================] - 0s 6ms/step - loss: 141.3009 - mape: 141.3009 - val_loss: 139.3131 - val_mape: 139.3131
# Epoch 14/200
# 19/19 [==============================] - 0s 6ms/step - loss: 135.7251 - mape: 135.7251 - val_loss: 133.8247 - val_mape: 133.8247
# Epoch 15/200
# 19/19 [==============================] - 0s 7ms/step - loss: 130.0103 - mape: 130.0103 - val_loss: 128.3227 - val_mape: 128.3227
# Epoch 16/200
# 19/19 [==============================] - 0s 6ms/step - loss: 124.2506 - mape: 124.2506 - val_loss: 122.7683 - val_mape: 122.7683
# Epoch 17/200
# 19/19 [==============================] - 0s 6ms/step - loss: 118.4460 - mape: 118.4460 - val_loss: 117.2239 - val_mape: 117.2239
# Epoch 18/200
# 19/19 [==============================] - 0s 7ms/step - loss: 112.7027 - mape: 112.7027 - val_loss: 111.7449 - val_mape: 111.7449
# Epoch 19/200
# 19/19 [==============================] - 0s 6ms/step - loss: 107.1044 - mape: 107.1044 - val_loss: 106.3710 - val_mape: 106.3710
# Epoch 20/200
# 19/19 [==============================] - 0s 5ms/step - loss: 101.5871 - mape: 101.5871 - val_loss: 101.0333 - val_mape: 101.0333
# Epoch 21/200
# 19/19 [==============================] - 0s 5ms/step - loss: 96.1688 - mape: 96.1688 - val_loss: 95.7639 - val_mape: 95.7639
# Epoch 22/200
# 19/19 [==============================] - 0s 7ms/step - loss: 90.8668 - mape: 90.8668 - val_loss: 90.5229 - val_mape: 90.5229
# Epoch 23/200
# 19/19 [==============================] - 0s 5ms/step - loss: 85.6539 - mape: 85.6539 - val_loss: 85.4215 - val_mape: 85.4215
# Epoch 24/200
# 19/19 [==============================] - 0s 6ms/step - loss: 80.5967 - mape: 80.5967 - val_loss: 80.5188 - val_mape: 80.5188
# Epoch 25/200
# 19/19 [==============================] - 0s 6ms/step - loss: 75.7413 - mape: 75.7413 - val_loss: 75.7743 - val_mape: 75.7743
# Epoch 26/200
# 19/19 [==============================] - 0s 6ms/step - loss: 71.1953 - mape: 71.1953 - val_loss: 71.2649 - val_mape: 71.2649
# Epoch 27/200
# 19/19 [==============================] - 0s 7ms/step - loss: 66.8832 - mape: 66.8832 - val_loss: 66.9584 - val_mape: 66.9584
# Epoch 28/200
# 19/19 [==============================] - 0s 6ms/step - loss: 62.6815 - mape: 62.6815 - val_loss: 62.7256 - val_mape: 62.7256
# Epoch 29/200
# 19/19 [==============================] - 0s 6ms/step - loss: 58.5264 - mape: 58.5264 - val_loss: 58.4659 - val_mape: 58.4659
# Epoch 30/200
# 19/19 [==============================] - 0s 5ms/step - loss: 54.3142 - mape: 54.3142 - val_loss: 54.1573 - val_mape: 54.1573
# Epoch 31/200
# 19/19 [==============================] - 0s 6ms/step - loss: 50.0807 - mape: 50.0807 - val_loss: 49.9824 - val_mape: 49.9824
# Epoch 32/200
# 19/19 [==============================] - 0s 6ms/step - loss: 45.8457 - mape: 45.8457 - val_loss: 45.9435 - val_mape: 45.9435
# Epoch 33/200
# 19/19 [==============================] - 0s 6ms/step - loss: 41.7095 - mape: 41.7095 - val_loss: 42.1514 - val_mape: 42.1514
# Epoch 34/200
# 19/19 [==============================] - 0s 5ms/step - loss: 37.7273 - mape: 37.7273 - val_loss: 38.7311 - val_mape: 38.7311
# Epoch 35/200
# 19/19 [==============================] - 0s 6ms/step - loss: 34.0942 - mape: 34.0942 - val_loss: 35.7067 - val_mape: 35.7067
# Epoch 36/200
# 19/19 [==============================] - 0s 5ms/step - loss: 30.8448 - mape: 30.8448 - val_loss: 32.8381 - val_mape: 32.8381
# Epoch 37/200
# 19/19 [==============================] - 0s 6ms/step - loss: 27.9753 - mape: 27.9753 - val_loss: 30.4955 - val_mape: 30.4955
# Epoch 38/200
# 19/19 [==============================] - 0s 5ms/step - loss: 25.6580 - mape: 25.6580 - val_loss: 28.4335 - val_mape: 28.4335
# Epoch 39/200
# 19/19 [==============================] - 0s 6ms/step - loss: 23.7500 - mape: 23.7500 - val_loss: 26.6832 - val_mape: 26.6832
# Epoch 40/200
# 19/19 [==============================] - 0s 6ms/step - loss: 22.3229 - mape: 22.3229 - val_loss: 25.2325 - val_mape: 25.2325
# Epoch 41/200
# 19/19 [==============================] - 0s 5ms/step - loss: 21.2584 - mape: 21.2584 - val_loss: 24.1704 - val_mape: 24.1704
# Epoch 42/200
# 19/19 [==============================] - 0s 6ms/step - loss: 20.5493 - mape: 20.5493 - val_loss: 23.2947 - val_mape: 23.2947
# Epoch 43/200
# 19/19 [==============================] - 0s 6ms/step - loss: 20.0034 - mape: 20.0034 - val_loss: 22.6278 - val_mape: 22.6278
# Epoch 44/200
# 19/19 [==============================] - 0s 5ms/step - loss: 19.6806 - mape: 19.6806 - val_loss: 22.0811 - val_mape: 22.0811
# Epoch 45/200
# 19/19 [==============================] - 0s 6ms/step - loss: 19.4322 - mape: 19.4322 - val_loss: 21.5957 - val_mape: 21.5957
# Epoch 46/200
# 19/19 [==============================] - 0s 6ms/step - loss: 19.2682 - mape: 19.2682 - val_loss: 21.2549 - val_mape: 21.2549
# Epoch 47/200
# 19/19 [==============================] - 0s 6ms/step - loss: 19.1256 - mape: 19.1256 - val_loss: 21.0704 - val_mape: 21.0704
# Epoch 48/200
# 19/19 [==============================] - 0s 5ms/step - loss: 19.0522 - mape: 19.0522 - val_loss: 20.9141 - val_mape: 20.9141
# Epoch 49/200
# 19/19 [==============================] - 0s 6ms/step - loss: 19.0102 - mape: 19.0102 - val_loss: 20.7926 - val_mape: 20.7926
# Epoch 50/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.9639 - mape: 18.9639 - val_loss: 20.7813 - val_mape: 20.7813
# Epoch 51/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.9467 - mape: 18.9467 - val_loss: 20.7314 - val_mape: 20.7314
# Epoch 52/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.9307 - mape: 18.9307 - val_loss: 20.7074 - val_mape: 20.7074
# Epoch 53/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.9146 - mape: 18.9146 - val_loss: 20.6755 - val_mape: 20.6755
# Epoch 54/200
# 19/19 [==============================] - 0s 7ms/step - loss: 18.9049 - mape: 18.9049 - val_loss: 20.6430 - val_mape: 20.6430
# Epoch 55/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.8945 - mape: 18.8945 - val_loss: 20.6300 - val_mape: 20.6300
# Epoch 56/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.8870 - mape: 18.8870 - val_loss: 20.6170 - val_mape: 20.6170
# Epoch 57/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.8792 - mape: 18.8792 - val_loss: 20.6123 - val_mape: 20.6123
# Epoch 58/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.8704 - mape: 18.8704 - val_loss: 20.6003 - val_mape: 20.6003
# Epoch 59/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.8634 - mape: 18.8634 - val_loss: 20.5900 - val_mape: 20.5900
# Epoch 60/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.8603 - mape: 18.8603 - val_loss: 20.5803 - val_mape: 20.5803
# Epoch 61/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.8513 - mape: 18.8513 - val_loss: 20.5864 - val_mape: 20.5864
# Epoch 62/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.8458 - mape: 18.8458 - val_loss: 20.5806 - val_mape: 20.5806
# Epoch 63/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.8389 - mape: 18.8389 - val_loss: 20.5832 - val_mape: 20.5832
# Epoch 64/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.8386 - mape: 18.8386 - val_loss: 20.5751 - val_mape: 20.5751
# Epoch 65/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.8285 - mape: 18.8285 - val_loss: 20.5746 - val_mape: 20.5746
# Epoch 66/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.8263 - mape: 18.8263 - val_loss: 20.5711 - val_mape: 20.5711
# Epoch 67/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.8159 - mape: 18.8159 - val_loss: 20.5558 - val_mape: 20.5558
# Epoch 68/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.8086 - mape: 18.8086 - val_loss: 20.5580 - val_mape: 20.5580
# Epoch 69/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.7999 - mape: 18.7999 - val_loss: 20.5519 - val_mape: 20.5519
# Epoch 70/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.7984 - mape: 18.7984 - val_loss: 20.5387 - val_mape: 20.5387
# Epoch 71/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.7882 - mape: 18.7882 - val_loss: 20.5431 - val_mape: 20.5431
# Epoch 72/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.7785 - mape: 18.7785 - val_loss: 20.5293 - val_mape: 20.5293
# Epoch 73/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.7734 - mape: 18.7734 - val_loss: 20.5210 - val_mape: 20.5210
# Epoch 74/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.7687 - mape: 18.7687 - val_loss: 20.5219 - val_mape: 20.5219
# Epoch 75/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.7603 - mape: 18.7603 - val_loss: 20.5118 - val_mape: 20.5118
# Epoch 76/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.7544 - mape: 18.7544 - val_loss: 20.5065 - val_mape: 20.5065
# Epoch 77/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.7473 - mape: 18.7473 - val_loss: 20.5099 - val_mape: 20.5099
# Epoch 78/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.7434 - mape: 18.7434 - val_loss: 20.5071 - val_mape: 20.5071
# Epoch 79/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.7419 - mape: 18.7419 - val_loss: 20.4873 - val_mape: 20.4873
# Epoch 80/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.7258 - mape: 18.7258 - val_loss: 20.4920 - val_mape: 20.4920
# Epoch 81/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.7205 - mape: 18.7205 - val_loss: 20.5035 - val_mape: 20.5035
# Epoch 82/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.7228 - mape: 18.7228 - val_loss: 20.5128 - val_mape: 20.5128
# Epoch 83/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.7134 - mape: 18.7134 - val_loss: 20.4777 - val_mape: 20.4777
# Epoch 84/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.7057 - mape: 18.7057 - val_loss: 20.4805 - val_mape: 20.4805
# Epoch 85/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.6934 - mape: 18.6934 - val_loss: 20.4679 - val_mape: 20.4679
# Epoch 86/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.6971 - mape: 18.6971 - val_loss: 20.4610 - val_mape: 20.4610
# Epoch 87/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.6834 - mape: 18.6834 - val_loss: 20.4589 - val_mape: 20.4589
# Epoch 88/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.6766 - mape: 18.6766 - val_loss: 20.4616 - val_mape: 20.4616
# Epoch 89/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.6754 - mape: 18.6754 - val_loss: 20.4986 - val_mape: 20.4986
# Epoch 90/200
# 19/19 [==============================] - 0s 7ms/step - loss: 18.6660 - mape: 18.6660 - val_loss: 20.4814 - val_mape: 20.4814
# Epoch 91/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.6568 - mape: 18.6568 - val_loss: 20.4741 - val_mape: 20.4741
# Epoch 92/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.6494 - mape: 18.6494 - val_loss: 20.4577 - val_mape: 20.4577
# Epoch 93/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.6553 - mape: 18.6553 - val_loss: 20.4656 - val_mape: 20.4656
# Epoch 94/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.6392 - mape: 18.6392 - val_loss: 20.4374 - val_mape: 20.4374
# Epoch 95/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.6282 - mape: 18.6282 - val_loss: 20.4364 - val_mape: 20.4364
# Epoch 96/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.6240 - mape: 18.6240 - val_loss: 20.4356 - val_mape: 20.4356
# Epoch 97/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.6171 - mape: 18.6171 - val_loss: 20.4345 - val_mape: 20.4345
# Epoch 98/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.6100 - mape: 18.6100 - val_loss: 20.4446 - val_mape: 20.4446
# Epoch 99/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.6028 - mape: 18.6028 - val_loss: 20.4392 - val_mape: 20.4392
# Epoch 100/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.5969 - mape: 18.5969 - val_loss: 20.4304 - val_mape: 20.4304
# Epoch 101/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.5889 - mape: 18.5889 - val_loss: 20.4304 - val_mape: 20.4304
# Epoch 102/200
# 19/19 [==============================] - 0s 7ms/step - loss: 18.5884 - mape: 18.5884 - val_loss: 20.4421 - val_mape: 20.4421
# Epoch 103/200
# 19/19 [==============================] - 0s 7ms/step - loss: 18.5789 - mape: 18.5789 - val_loss: 20.4155 - val_mape: 20.4155
# Epoch 104/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.5695 - mape: 18.5695 - val_loss: 20.4119 - val_mape: 20.4119
# Epoch 105/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.5621 - mape: 18.5621 - val_loss: 20.4227 - val_mape: 20.4227
# Epoch 106/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.5564 - mape: 18.5564 - val_loss: 20.4249 - val_mape: 20.4249
# Epoch 107/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.5487 - mape: 18.5487 - val_loss: 20.4150 - val_mape: 20.4150
# Epoch 108/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.5440 - mape: 18.5440 - val_loss: 20.4151 - val_mape: 20.4151
# Epoch 109/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.5378 - mape: 18.5378 - val_loss: 20.4150 - val_mape: 20.4150
# Epoch 110/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.5277 - mape: 18.5277 - val_loss: 20.4116 - val_mape: 20.4116
# Epoch 111/200
# 19/19 [==============================] - 0s 7ms/step - loss: 18.5217 - mape: 18.5217 - val_loss: 20.4107 - val_mape: 20.4107
# Epoch 112/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.5144 - mape: 18.5144 - val_loss: 20.4139 - val_mape: 20.4139
# Epoch 113/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.5151 - mape: 18.5151 - val_loss: 20.4402 - val_mape: 20.4402
# Epoch 114/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.5017 - mape: 18.5017 - val_loss: 20.4207 - val_mape: 20.4207
# Epoch 115/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.4936 - mape: 18.4936 - val_loss: 20.4117 - val_mape: 20.4117
# Epoch 116/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.4902 - mape: 18.4902 - val_loss: 20.4103 - val_mape: 20.4103
# Epoch 117/200
# 19/19 [==============================] - 0s 7ms/step - loss: 18.4873 - mape: 18.4873 - val_loss: 20.3982 - val_mape: 20.3982
# Epoch 118/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.4765 - mape: 18.4765 - val_loss: 20.4025 - val_mape: 20.4025
# Epoch 119/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.4678 - mape: 18.4678 - val_loss: 20.4122 - val_mape: 20.4122
# Epoch 120/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.4645 - mape: 18.4645 - val_loss: 20.4103 - val_mape: 20.4103
# Epoch 121/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.4544 - mape: 18.4544 - val_loss: 20.4236 - val_mape: 20.4236
# Epoch 122/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.4488 - mape: 18.4488 - val_loss: 20.4243 - val_mape: 20.4243
# Epoch 123/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.4440 - mape: 18.4440 - val_loss: 20.4161 - val_mape: 20.4161
# Epoch 124/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.4375 - mape: 18.4375 - val_loss: 20.4071 - val_mape: 20.4071
# Epoch 125/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.4284 - mape: 18.4284 - val_loss: 20.4232 - val_mape: 20.4232
# Epoch 126/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.4217 - mape: 18.4217 - val_loss: 20.4046 - val_mape: 20.4046
# Epoch 127/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.4139 - mape: 18.4139 - val_loss: 20.4096 - val_mape: 20.4096
# Epoch 128/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.4072 - mape: 18.4072 - val_loss: 20.4102 - val_mape: 20.4102
# Epoch 129/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.4159 - mape: 18.4159 - val_loss: 20.3903 - val_mape: 20.3903
# Epoch 130/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.3942 - mape: 18.3942 - val_loss: 20.4028 - val_mape: 20.4028
# Epoch 131/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.3883 - mape: 18.3883 - val_loss: 20.4060 - val_mape: 20.4060
# Epoch 132/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.3805 - mape: 18.3805 - val_loss: 20.3937 - val_mape: 20.3937
# Epoch 133/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.3806 - mape: 18.3806 - val_loss: 20.3870 - val_mape: 20.3870
# Epoch 134/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.3827 - mape: 18.3827 - val_loss: 20.4085 - val_mape: 20.4085
# Epoch 135/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.3630 - mape: 18.3630 - val_loss: 20.3996 - val_mape: 20.3996
# Epoch 136/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.3649 - mape: 18.3649 - val_loss: 20.3828 - val_mape: 20.3828
# Epoch 137/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.3601 - mape: 18.3601 - val_loss: 20.4055 - val_mape: 20.4055
# Epoch 138/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.3423 - mape: 18.3423 - val_loss: 20.3922 - val_mape: 20.3922
# Epoch 139/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.3395 - mape: 18.3395 - val_loss: 20.3842 - val_mape: 20.3842
# Epoch 140/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.3337 - mape: 18.3337 - val_loss: 20.3906 - val_mape: 20.3906
# Epoch 141/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.3258 - mape: 18.3258 - val_loss: 20.3914 - val_mape: 20.3914
# Epoch 142/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.3227 - mape: 18.3227 - val_loss: 20.3870 - val_mape: 20.3870
# Epoch 143/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.3154 - mape: 18.3154 - val_loss: 20.3813 - val_mape: 20.3813
# Epoch 144/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.3108 - mape: 18.3108 - val_loss: 20.3963 - val_mape: 20.3963
# Epoch 145/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2989 - mape: 18.2989 - val_loss: 20.3852 - val_mape: 20.3852
# Epoch 146/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.3015 - mape: 18.3015 - val_loss: 20.3762 - val_mape: 20.3762
# Epoch 147/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.2936 - mape: 18.2936 - val_loss: 20.3834 - val_mape: 20.3834
# Epoch 148/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2819 - mape: 18.2819 - val_loss: 20.3822 - val_mape: 20.3822
# Epoch 149/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.2837 - mape: 18.2837 - val_loss: 20.3722 - val_mape: 20.3722
# Epoch 150/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2820 - mape: 18.2820 - val_loss: 20.3877 - val_mape: 20.3877
# Epoch 151/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2608 - mape: 18.2608 - val_loss: 20.3742 - val_mape: 20.3742
# Epoch 152/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.2582 - mape: 18.2582 - val_loss: 20.3735 - val_mape: 20.3735
# Epoch 153/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2518 - mape: 18.2518 - val_loss: 20.3822 - val_mape: 20.3822
# Epoch 154/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.2579 - mape: 18.2579 - val_loss: 20.3767 - val_mape: 20.3767
# Epoch 155/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2430 - mape: 18.2430 - val_loss: 20.3907 - val_mape: 20.3907
# Epoch 156/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2348 - mape: 18.2348 - val_loss: 20.3872 - val_mape: 20.3872
# Epoch 157/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.2421 - mape: 18.2421 - val_loss: 20.3712 - val_mape: 20.3712
# Epoch 158/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.2306 - mape: 18.2306 - val_loss: 20.3755 - val_mape: 20.3755
# Epoch 159/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2173 - mape: 18.2173 - val_loss: 20.3679 - val_mape: 20.3679
# Epoch 160/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2126 - mape: 18.2126 - val_loss: 20.3739 - val_mape: 20.3739
# Epoch 161/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2103 - mape: 18.2103 - val_loss: 20.3709 - val_mape: 20.3709
# Epoch 162/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.2026 - mape: 18.2026 - val_loss: 20.3804 - val_mape: 20.3804
# Epoch 163/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.1979 - mape: 18.1979 - val_loss: 20.3673 - val_mape: 20.3673
# Epoch 164/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.1937 - mape: 18.1937 - val_loss: 20.3625 - val_mape: 20.3625
# Epoch 165/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.1799 - mape: 18.1799 - val_loss: 20.3735 - val_mape: 20.3735
# Epoch 166/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.1759 - mape: 18.1759 - val_loss: 20.3652 - val_mape: 20.3652
# Epoch 167/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.1712 - mape: 18.1712 - val_loss: 20.3638 - val_mape: 20.3638
# Epoch 168/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.1648 - mape: 18.1648 - val_loss: 20.3655 - val_mape: 20.3655
# Epoch 169/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.1657 - mape: 18.1657 - val_loss: 20.3553 - val_mape: 20.3553
# Epoch 170/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.1597 - mape: 18.1597 - val_loss: 20.3781 - val_mape: 20.3781
# Epoch 171/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.1571 - mape: 18.1571 - val_loss: 20.3550 - val_mape: 20.3550
# Epoch 172/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.1489 - mape: 18.1489 - val_loss: 20.3793 - val_mape: 20.3793
# Epoch 173/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.1411 - mape: 18.1411 - val_loss: 20.3821 - val_mape: 20.3821
# Epoch 174/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.1307 - mape: 18.1307 - val_loss: 20.3604 - val_mape: 20.3604
# Epoch 175/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.1297 - mape: 18.1297 - val_loss: 20.3762 - val_mape: 20.3762
# Epoch 176/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.1184 - mape: 18.1184 - val_loss: 20.3566 - val_mape: 20.3566
# Epoch 177/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.1148 - mape: 18.1148 - val_loss: 20.3550 - val_mape: 20.3550
# Epoch 178/200
# 19/19 [==============================] - 0s 7ms/step - loss: 18.1106 - mape: 18.1106 - val_loss: 20.3559 - val_mape: 20.3559
# Epoch 179/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.1005 - mape: 18.1005 - val_loss: 20.3734 - val_mape: 20.3734
# Epoch 180/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.1040 - mape: 18.1040 - val_loss: 20.3649 - val_mape: 20.3649
# Epoch 181/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.0907 - mape: 18.0907 - val_loss: 20.3712 - val_mape: 20.3712
# Epoch 182/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.0881 - mape: 18.0881 - val_loss: 20.3711 - val_mape: 20.3711
# Epoch 183/200
# 19/19 [==============================] - 0s 7ms/step - loss: 18.0834 - mape: 18.0834 - val_loss: 20.3751 - val_mape: 20.3751
# Epoch 184/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.0763 - mape: 18.0763 - val_loss: 20.3629 - val_mape: 20.3629
# Epoch 185/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.0707 - mape: 18.0707 - val_loss: 20.3685 - val_mape: 20.3685
# Epoch 186/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.0652 - mape: 18.0652 - val_loss: 20.3668 - val_mape: 20.3668
# Epoch 187/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.0580 - mape: 18.0580 - val_loss: 20.3557 - val_mape: 20.3557
# Epoch 188/200
# 19/19 [==============================] - 0s 7ms/step - loss: 18.0504 - mape: 18.0504 - val_loss: 20.3607 - val_mape: 20.3607
# Epoch 189/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.0677 - mape: 18.0677 - val_loss: 20.3807 - val_mape: 20.3807
# Epoch 190/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.0462 - mape: 18.0462 - val_loss: 20.3511 - val_mape: 20.3511
# Epoch 191/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.0365 - mape: 18.0365 - val_loss: 20.3460 - val_mape: 20.3460
# Epoch 192/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.0385 - mape: 18.0385 - val_loss: 20.3712 - val_mape: 20.3712
# Epoch 193/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.0234 - mape: 18.0234 - val_loss: 20.3627 - val_mape: 20.3627
# Epoch 194/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.0182 - mape: 18.0182 - val_loss: 20.3568 - val_mape: 20.3568
# Epoch 195/200
# 19/19 [==============================] - 0s 6ms/step - loss: 18.0152 - mape: 18.0152 - val_loss: 20.3536 - val_mape: 20.3536
# Epoch 196/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.0069 - mape: 18.0069 - val_loss: 20.3663 - val_mape: 20.3663
# Epoch 197/200
# 19/19 [==============================] - 0s 5ms/step - loss: 18.0070 - mape: 18.0070 - val_loss: 20.3692 - val_mape: 20.3692
# Epoch 198/200
# 19/19 [==============================] - 0s 6ms/step - loss: 17.9957 - mape: 17.9957 - val_loss: 20.3789 - val_mape: 20.3789
# Epoch 199/200
# 19/19 [==============================] - 0s 5ms/step - loss: 17.9965 - mape: 17.9965 - val_loss: 20.3766 - val_mape: 20.3766
# Epoch 200/200
# 19/19 [==============================] - 0s 5ms/step - loss: 17.9940 - mape: 17.9940 - val_loss: 20.3883 - val_mape: 20.3883

# %%
def model_loss(history):
    plt.figure(figsize=(8,4))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Test Loss')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(loc='upper right')
    plt.show();

# %%
train_score = model.evaluate(trainX, trainY, verbose=0)
print('Train MAPE: %.2f' % ((train_score[1])))
test_score = model.evaluate(testX, testY, verbose=0)
print('Test MAPE: %.2f' % (test_score[1]))
model_loss(model_history)
# Out:
# Train MAPE: 17.98
# Test MAPE: 20.39

# %%
import seaborn as sns

# %%
def prediction_plot(testY, test_predict):
    len_prediction=[x for x in range(611,681)]
    plt.figure(figsize=(15,8))
    plt.plot(trainY)
    plt.plot(len_prediction, testY, marker='.', label="actual")
    plt.plot(len_prediction, test_predict, 'g', label="prediction")
    plt.tight_layout()
    sns.despine(top=True)
    plt.subplots_adjust(left=0.07)
    plt.ylabel('Units', size=15)
    plt.xlabel('Time step', size=15)
    plt.legend(fontsize=15)
    plt.show();

# %%
test_predict = model.predict(testX)
prediction_plot(testY, test_predict)
